# %% [markdown]
# # 6.1 Trabajo a futuro.
#
# Contar con una guía en español de instalación de Virtual Box, Linux y Quantum Espresso, así como una guía básica de uso, con ejercicios representativos de Quantum Expresso puede ser de entrada una útil herramienta para cursos o talleres de introducción a estructura electrónica, teoría funcional de la densidad o similares. Esta guía podría servir para estudiantes de último año de licenciaturas o de primer año de posgrado, para que guiados paso a paso se familiaricen con el entorno y el programa.
# Además, utilizar herramientas como Phyton, XCrySDen, Jupyter-notebook, Virtual Box, y contar con la información en un repositorio de GitHub, permite practicar y desarrollar competencias más allá del conocimiento del código. Este primer trabajo puede ser la base para crecer y contar con múltiples ejercicios tanto de programación como de estado sólido y DFT.
# * A futuro cercano una perspectiva es utilizar esta guía y mejorarla en trabajos de titulación a nivel licenciatura.
# * A mediano plazo, la idea es ir alimentando el repositorio con más ejercicios y ejemplos cubriendo algunas de las muchas opciones que ofrece QE, como cálculo de fonones, cálculos de dinámica molecular, creación de pseudopotenciales, etc.
# * A largo plazo, se podría pensar en una colaboración con otras universidades para que estudiantes e investigadores de diferentes zonas de Latinoamérica participen en este proyecto.
#
# # 6.2 Conclusiones.
#
# 1. No realicé un estudio de factibilidad del uso de QE en la Ibero, pues como menciono en el primer notebook, desde el comienzo encontré que no era solo extremadamente factible, sino que existen multitudes aproximaciones diferentes al uso de QE a nivel licenciatura.
#
# 2. El presente trabajo se convirtió en una guía paso a paso para trabajar QE en una laptop, para que cualquier estudiante pueda utilizar el programa.
#
# 3. Aquí se muestra la integración de un administrador de máquinas virtuales para instalar un sistema operativo Linux en un sistema anfitrión Windows, para la instalación de Quantum Espresso, Python y Anaconda, generando diferentes *notebooks* que pueden ser utilizados como guía para estudiantes, en el uso de algunos ejercicios de Quantum Espresso, analizados con Python y reportados en Jupyter-notebooks.
#
#
# # 6.3 Agradecimientos.
#
# El apoyo de Dominique Brun en la dirección de Física y Matemáticas, me dio la libertad de plantear un proyecto como este. Por eso y por su ayuda en diferentes trámites del sabático, posponerlo y estar al tanto, procurando que tenga las herramientas para trabajar, le estoy enormemente agradecido.
#
# Ángel Reyes, amigo, ejemplo de tenacidad y vitalidad, así como solucionador constante (de dudas de programación o especificidades de QE) y con una enorme disposición, merece mi mas grande agradecimiento.
#
# A todo el grupo de Mauricio Terrones en la Universidad Estatal de Pensilvania, a Mauricio por financiamiento y a mis amigas Lucía y Ana Elías, les agradezco su cálida compañía en los momentos en los que no estaba haciendo experimentos o escribiendo este trabajo.
#
# A algún lector que tenga comentarios, sugerencias o preguntas para mejorar este trabajo, de antemano mi agradecimiento.

# %% [markdown]
# [Ir al notebook anterior.](band-structre_and_DOS_Si.ipynb)
#
# [Ir al primer notebook](Propuesta.ipynb)
